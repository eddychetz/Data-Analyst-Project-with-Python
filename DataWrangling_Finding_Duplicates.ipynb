# %% [markdown]
# <a href="https://colab.research.google.com/github/eddychetz/Data-Analytics-and-Visualization-Capstone-Project-with-Python/blob/main/DataWrangling_Finding_Duplicates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab: Finding Duplicates**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/Capstone_edX/Module%201/survey_results_public_2020.csv")
df.head()
# Out:
#    Respondent  ... YearsCodePro
# 0           1  ...           27
# 1           2  ...            4
# 2           3  ...          NaN
# 3           4  ...            4
# 4           5  ...            8
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
df["is_duplicate"]=df.duplicated()

# %%
df["is_duplicate"].value_counts()
# Out:
# False    64461
# Name: is_duplicate, dtype: int64

# %% [markdown]
# It seems like there are no duplicates now.

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
# drop duplicate rows
df = df.drop_duplicates()

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
# Selecting duplicate rows based on all columns.
duplicate = df[df.duplicated()]
print("Duplicate Rows :")
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [Respondent, MainBranch, Hobbyist, Age, Age1stCode, CompFreq, CompTotal, ConvertedComp, Country, CurrencyDesc, CurrencySymbol, DatabaseDesireNextYear, DatabaseWorkedWith, DevType, EdLevel, Employment, Ethnicity, Gender, JobFactors, JobSat, JobSeek, LanguageDesireNextYear, LanguageWorkedWith, MiscTechDesireNextYear, MiscTechWorkedWith, NEWCollabToolsDesireNextYear, NEWCollabToolsWorkedWith, NEWDevOps, NEWDevOpsImpt, NEWEdImpt, NEWJobHunt, NEWJobHuntResearch, NEWLearn, NEWOffTopic, NEWOnboardGood, NEWOtherComms, NEWOvertime, NEWPurchaseResearch, NEWPurpleLink, NEWSOSites, NEWStuck, OpSys, OrgSize, PlatformDesireNextYear, PlatformWorkedWith, PurchaseWhat, Sexuality, SOAccount, SOComm, SOPartFreq, SOVisitFreq, SurveyEase, SurveyLength, Trans, UndergradMajor, WebframeDesireNextYear, WebframeWorkedWith, WelcomeChange, WorkWeekHrs, YearsCode, YearsCodePro, is_duplicate]
# Index: []

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
df.apply(lambda x: sum(x.isnull().values), axis = 0)
# Out:
# Respondent           0
# MainBranch         299
# Hobbyist            45
# Age              19015
# Age1stCode        6561
#                  ...
# WelcomeChange    11778
# WorkWeekHrs      23310
# YearsCode         6777
# YearsCodePro     18112
# is_duplicate         0
# Length: 62, dtype: int64

# %%
# your code goes here
df.isnull().sum().sort_values(ascending=False)/len(df)
# Out:
# ConvertedComp             0.460821
# CompTotal                 0.459735
# NEWPurchaseResearch       0.421030
# PurchaseWhat              0.389336
# WebframeDesireNextYear    0.379097
#                             ...
# Country                   0.006035
# MainBranch                0.004638
# Hobbyist                  0.000698
# is_duplicate              0.000000
# Respondent                0.000000
# Length: 62, dtype: float64

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column Age.

# %%
# your code goes here
df.Age.value_counts()
# Out:
# 25.0    2693
# 28.0    2412
# 30.0    2406
# 26.0    2391
# 27.0    2338
#         ...
# 23.8       1
# 95.0       1
# 31.5       1
# 20.5       1
# 16.5       1
# Name: Age, Length: 110, dtype: int64

# %% [markdown]
# Find the median for the column Age

# %%
#your code goes here
median_age = df.Age.median()
median_age
# Out:
# 29.0

# %% [markdown]
# Impute the median value to Age column

# %%
# your code goes here
import numpy as np
df["Age"].replace(np.nan, median_age, inplace=True)

# %% [markdown]
# Identify the value that is most frequent (majority) in the Country column.

# %%
# your code goes here
print("The country which appears frequently in the survey is: ", df.Country.mode())
# Out:
# The country which appears frequently in the survey is:  0    United States
# dtype: object

# %% [markdown]
# Drop all the missing values from the dataset

# %%
# your code goes here
df_final = df.dropna()    # Dropping the missing values.
df_final.count()
# Out:
# Respondent       4387
# MainBranch       4387
# Hobbyist         4387
# Age              4387
# Age1stCode       4387
#                  ...
# WelcomeChange    4387
# WorkWeekHrs      4387
# YearsCode        4387
# YearsCodePro     4387
# is_duplicate     4387
# Length: 62, dtype: int64

# %%
print(df_final.isnull().sum())
# Out:
# Respondent       0
# MainBranch       0
# Hobbyist         0
# Age              0
# Age1stCode       0
#                 ..
# WelcomeChange    0
# WorkWeekHrs      0
# YearsCode        0
# YearsCodePro     0
# is_duplicate     0
# Length: 62, dtype: int64

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
compfreq_cat = df_final['CompFreq'].unique()
compfreq_cat
# Out:
# array(['Yearly', 'Monthly', 'Weekly'], dtype=object)

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
df_final['NormalizedAnnualCompensation'] = np.where(df_final['CompFreq']=='Monthly', 
                                              df_final['CompTotal']*12, 
                                              df_final['CompTotal'])
df_month = df_final
df_month = df_month.loc[df_month['CompFreq']=='Monthly']
df_month.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      Respondent  ... NormalizedAnnualCompensation
# 32           33  ...                      58800.0
# 94           96  ...                     120000.0
# 149         151  ...                     240000.0
# 159         161  ...                      33600.0
# 240         242  ...                     300000.0
#
# [5 rows x 63 columns]

# %%
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
df_final['NormalizedAnnualCompensation'] = np.where(df_final['CompFreq']=='Weekly', 
                                                    df_final['CompTotal']*52, 
                                                    df_final['NormalizedAnnualCompensation'])
df_week = df_final
df_week = df_week.loc[df_week['CompFreq']=='Weekly']
df_week.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       Respondent  ... NormalizedAnnualCompensation
# 121          123  ...                    6240000.0
# 982          986  ...                    4212000.0
# 1022        1026  ...                      54600.0
#
# [3 rows x 63 columns]

# %%
df_final.Respondent.nunique()
# Out:
# 4387

# %%
df_final.shape
# Out:
# (4387, 63)

# %%
df_final.merge(df_month, on='Respondent', how='inner')
df_final.head()
# Out:
#     Respondent  ... NormalizedAnnualCompensation
# 9           10  ...                      25000.0
# 32          33  ...                      58800.0
# 41          42  ...                     130000.0
# 46          47  ...                      58000.0
# 68          69  ...                     550000.0
#
# [5 rows x 63 columns]

# %%
df_final.merge(df_week, on='Respondent', how='inner')
df_final.head()
# Out:
#     Respondent  ... NormalizedAnnualCompensation
# 9           10  ...                      25000.0
# 32          33  ...                      58800.0
# 41          42  ...                     130000.0
# 46          47  ...                      58000.0
# 68          69  ...                     550000.0
#
# [5 rows x 63 columns]

# %%
df_final[['CompFreq','CompTotal','NormalizedAnnualCompensation']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4387 entries, 9 to 63517
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CompFreq                      4387 non-null   object
#  1   CompTotal                     4387 non-null   float64
#  2   NormalizedAnnualCompensation  4387 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 137.1+ KB

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
