# %% [markdown]
# <a href="https://colab.research.google.com/github/eddychetz/Data-Analytics-and-Visualization-Capstone-Project-with-Python/blob/main/Data_Wrangling_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab: Introduction**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")
df.head()
# Out:
#    Respondent  ...                  SurveyEase
# 0           4  ...                        Easy
# 1           9  ...  Neither easy nor difficult
# 2          13  ...                        Easy
# 3          16  ...  Neither easy nor difficult
# 4          17  ...                        Easy
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
#creating a column showing if row is duplicated or not
df["is_duplicate"]=df.duplicated()

# %%
#counting rows with duplicates and that are not duplicated. 154 duplicates and 11398 non-duplicates
df["is_duplicate"].value_counts()
# Out:
# False    11398
# True       154
# Name: is_duplicate, dtype: int64

# %% [markdown]
# There are 154 duplicated rows.

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# drop duplicate rows
df_uniq = df.drop_duplicates()

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
#number of rows before removing duplicates
print("There are ",df.shape[0]," number of rows before removing duplicates.")
#number of rows after removing duplicates
print("There are ",df_uniq.shape[0]," number of rows after removing duplicates.")
#confirming number of duplicates removed
print("We dropped ",df.shape[0] - df_uniq.shape[0]," rows in the dataframe.")
# Out:
# There are  11552  number of rows before removing duplicates.
# There are  11491  number of rows after removing duplicates.
# We dropped  61  rows in the dataframe.

# %%
# Selecting duplicate rows based on all columns.
duplicate = df_uniq[df_uniq.duplicated()]
print("Duplicate Rows :")
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# ...

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
df_uniq.apply(lambda x: sum(x.isnull().values), axis = 0)
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Ethnicity       680
# Dependents      142
# SurveyLength     19
# SurveyEase       14
# is_duplicate      0
# Length: 86, dtype: int64

# %%
df_uniq.isnull().sum().sort_values(ascending=False)/len(df_uniq)
# Out:
# BlockchainIs          0.228527
# CodeRevHrs            0.213384
# BlockchainOrg         0.203899
# MiscTechWorkedWith    0.191193
# SONewContent          0.172744
#                         ...
# LastHireDate          0.000000
# CurrencySymbol        0.000000
# CurrencyDesc          0.000000
# SOComm                0.000000
# Respondent            0.000000
# Length: 86, dtype: float64

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
sum(df_uniq[["WorkLoc"]].isnull().values.ravel())
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
df_uniq["WorkLoc"].value_counts()
# Out:
# Office                                            6865
# Home                                              3619
# Other place, such as a coworking space or cafe     975
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
#
workloc_major = df_uniq.WorkLoc.mode()
workloc_major
# Out:
# 0    Office
# dtype: object

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
import numpy as np
df_uniq.WorkLoc.replace(np.nan, 'Office', inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:4582: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
df_uniq[["WorkLoc"]].isnull().any()
# Out:
# WorkLoc    False
# dtype: bool

# %%
# check sum of null values avaiable
sum(df_uniq[["WorkLoc"]].isnull().values.ravel())
# Out:
# 0

# %%
df_uniq["WorkLoc"].describe()
# Out:
# count      11491
# unique         3
# top       Office
# freq        6897
# Name: WorkLoc, dtype: object

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
df_uniq['CompFreq'].unique()
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
df_uniq['NormalizedAnnualCompensation'] = np.where(df_uniq['CompFreq']=='Monthly', 
                                              df_uniq['CompTotal']*12, 
                                              df_uniq['CompTotal'])
df_month = df_uniq
df_month = df_month.loc[df_month['CompFreq']=='Monthly']
df_month.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     Respondent  ... NormalizedAnnualCompensation
# 3           16  ...                     348000.0
# 5           19  ...                     114000.0
# 6           20  ...                      36000.0
# 9           24  ...                      96000.0
# 10          25  ...                      84000.0
#
# [5 rows x 87 columns]

# %%
df_uniq['NormalizedAnnualCompensation'] = np.where(df_uniq['CompFreq']=='Weekly', 
                                                    df_uniq['CompTotal']*52, 
                                                    df_uniq['NormalizedAnnualCompensation'])
df_week = df_uniq
df_week = df_week.loc[df_week['CompFreq']=='Weekly']
df_week.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     Respondent  ... NormalizedAnnualCompensation
# 12          29  ...                     104000.0
# 13          32  ...                    1144000.0
# 46         102  ...                    3525600.0
#
# [3 rows x 87 columns]

# %%
df_uniq.shape
# Out:
# (11491, 87)

# %%
df_uniq.merge(df_week, on = 'Respondent', how='inner')
df_uniq.head()
# Out:
#    Respondent  ... NormalizedAnnualCompensation
# 0           4  ...                      61000.0
# 1           9  ...                     138000.0
# 2          13  ...                      90000.0
# 3          16  ...                     348000.0
# 4          17  ...                      90000.0
#
# [5 rows x 87 columns]

# %%
df_uniq.merge(df_month, on = 'Respondent', how='inner')
df_uniq.head()
# Out:
#    Respondent  ... NormalizedAnnualCompensation
# 0           4  ...                      61000.0
# 1           9  ...                     138000.0
# 2          13  ...                      90000.0
# 3          16  ...                     348000.0
# 4          17  ...                      90000.0
#
# [5 rows x 87 columns]

# %%
df_uniq[['CompTotal','CompFreq','NormalizedAnnualCompensation']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11491 entries, 0 to 11551
# Data columns (total 3 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CompTotal                     10678 non-null  float64
#  1   CompFreq                      11285 non-null  object
#  2   NormalizedAnnualCompensation  10678 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 359.1+ KB

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
